# %% [markdown]
# # Artificial Intelligence

# %% [markdown]
# The effort to automate intellectual tasks normally performed by humans.

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ![Screenshot 2025-07-28 215349.png](attachment:eb46b1d2-7a7a-4234-bd00-b6a753ec3795.png)

# %% [markdown]
# It figure outs the rules for us. We load the data as inputs and outputs. And Machine learning figure outs the solution by set of rules.

# %% [markdown]
# ![Screenshot 2025-07-28 215601.png](attachment:15b3ef51-1e76-435e-9cd7-082b3cd08dc8.png)

# %% [markdown]
# Goal for machine learning models : Highest Accuracy possible.

# %% [markdown]
# Rather than giving the program the rules, an algorithm finds out the rules for us.

# %% [markdown]
# # Neural Network

# %% [markdown]
# ![Screenshot 2025-07-28 220233.png](attachment:243fb09b-e18d-4547-9da0-e84ac06abb17.png)

# %% [markdown]
# A form of machine learning that uses a layered representation of data.

# %% [markdown]
# ![Screenshot 2025-07-28 220709.png](attachment:097a04a8-1e8c-425c-b39d-42895ef5693b.png)
